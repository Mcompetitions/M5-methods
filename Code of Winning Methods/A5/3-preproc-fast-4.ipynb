# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

pd.options.display.max_columns = 50

import random
from  datetime import datetime, timedelta

import lightgbm as lgb

# %%
CAL_DTYPES={"event_name_1": "category", "event_name_2": "category", "event_type_1": "category", 
         "event_type_2": "category", "weekday": "category", 'wm_yr_wk': 'int16', "wday": "int16",
        "month": "int16", "year": "int16", "snap_CA": "float32", 'snap_TX': 'float32', 'snap_WI': 'float32' }
PRICE_DTYPES = {"store_id": "category", "item_id": "category", "wm_yr_wk": "int16","sell_price":"float32", 
                "rm_diff_price_4":"float32", "rm_diff_price_12":"float32","rm_diff_price_50":"float32" }
PROC_PRICES_DTYPES = {"store_id": "category", "item_id": "category", "wm_yr_wk": "int16", 
                        "rm_diff_price_4":"float32", "rm_diff_price_12":"float32","rm_diff_price_50":"float32" }

# %%
h = 28 
max_lags = 70
tr_last = 1941
fday = datetime(2016,5, 23) 
fday
# Out:
# datetime.datetime(2016, 5, 23, 0, 0)

# %%
def create_dt(is_train = True, nrows = None, first_day = 1200, dept='HOBBIES_1'):
    prices = pd.read_csv("./raw_data/sell_prices.csv", dtype = PRICE_DTYPES)
    proc_price = pd.read_csv('./proc_data/prices_processed.csv', dtype = PROC_PRICES_DTYPES).drop('sell_price', axis=1)
    prices = prices.merge(proc_price, on=['store_id','item_id','wm_yr_wk'], how='left')
    del(proc_price)
    
    for col, col_dtype in PRICE_DTYPES.items():
        if col_dtype == "category":
            prices[col] = prices[col].cat.codes.astype("int16")
            prices[col] -= prices[col].min()
            
    cal = pd.read_csv("./raw_data/calendar.csv", dtype = CAL_DTYPES)
    proc_cal = pd.read_csv('./proc_data/processed_calendar.csv').drop(
    ['wm_yr_wk','wday','month','year','snap_CA','snap_TX','snap_WI'], axis=1).rename(columns={'day':'d'})
    cols_events_days = ['d_{}'.format(c) for c in list(np.arange(1910,1990))]
    ev1 = cal[cal['d'].isin(cols_events_days)]['event_name_1'].unique().tolist()
    ev2 = cal[cal['d'].isin(cols_events_days)]['event_name_2'].unique().tolist()
    evs = list(set(ev1+ev2))
    for c in list(set(proc_cal.columns.tolist()) - set(['d'])):
        proc_cal[c] = proc_cal[c].astype(int)
    cal = cal.merge(proc_cal, on='d', how='left')
    cal["date"] = pd.to_datetime(cal["date"])
    for col, col_dtype in CAL_DTYPES.items():
        if col_dtype == "category":
            cal[col] = cal[col].cat.codes.astype("int16")
            cal[col] -= cal[col].min()
    events_to_mantain = ['event_name_1_{}'.format(c) for c in evs]+['event_name_2_{}'.format(c) for c in evs]
    events_to_mantain_ = [c for c in cal.columns if c in events_to_mantain]
    cal = cal[['date','wm_yr_wk','weekday','wday','month','year','d','event_name_1','event_type_1','event_name_2',
               'event_type_2','snap_CA','snap_TX','snap_WI','group_day']+events_to_mantain_]
    
    start_day = max(1 if is_train  else tr_last-max_lags, first_day)
    numcols = [f"d_{day}" for day in range(start_day,tr_last+1)]
    catcols = ['id', 'item_id', 'dept_id','store_id', 'cat_id', 'state_id']
    dtype = {numcol:"float32" for numcol in numcols} 
    dtype.update({col: "category" for col in catcols if col != "id"})
    dt = pd.read_csv("./raw_data/sales_train_evaluation.csv", 
                     nrows = nrows, usecols = catcols + numcols, dtype = dtype)
    dt = dt[dt['dept_id']==dept]
    
    for col in catcols:
        if col != "id":
            dt[col] = dt[col].cat.codes.astype("int16")
            dt[col] -= dt[col].min()
    
    if not is_train:
        for day in range(tr_last+1, tr_last+ 28 +1):
            dt[f"d_{day}"] = np.nan
    
    dt = pd.melt(dt,
                  id_vars = catcols,
                  value_vars = [col for col in dt.columns if col.startswith("d_")],
                  var_name = "d",
                  value_name = "sales")
    
    dt = dt.merge(cal, on= "d", copy = False)
    dt = dt.merge(prices, on = ["store_id", "item_id", "wm_yr_wk"], copy = False)
    
    return dt

# %%
def create_fea(dt):
    lags = [7, 28]
    lag_cols = [f"lag_{lag}" for lag in lags ]
    for lag, lag_col in zip(lags, lag_cols):
        dt[lag_col] = dt[["id","sales"]].groupby("id")["sales"].shift(lag)

    wins = [7, 28]
    for win in wins :
        for lag,lag_col in zip(lags, lag_cols):
            dt[f"rmean_{lag}_{win}"] = dt[["id", lag_col]].groupby("id")[lag_col].transform(lambda x : x.rolling(win).mean())

    
    
    date_features = {
        
        "wday": "weekday",
        "week": "weekofyear",
        "month": "month",
        "quarter": "quarter",
        "year": "year",
        "mday": "day",
#         "ime": "is_month_end",
#         "ims": "is_month_start",
    }
    
#     dt.drop(["d", "wm_yr_wk", "weekday"], axis=1, inplace = True)
    
    for date_feat_name, date_feat_func in date_features.items():
        if date_feat_name in dt.columns:
            dt[date_feat_name] = dt[date_feat_name].astype("int16")
        else:
            dt[date_feat_name] = getattr(dt["date"].dt, date_feat_func).astype("int16")

# %%
FIRST_DAY = 350

# %%
# %%time

sub_p_total = pd.DataFrame()
for dept in ['HOBBIES_1', 'HOBBIES_2', 'HOUSEHOLD_1', 'HOUSEHOLD_2', 'FOODS_1', 'FOODS_2', 'FOODS_3']:
#for dept in ['HOBBIES_1']:

    df = create_dt(is_train=True, first_day= FIRST_DAY, dept=dept)
    print(df.shape)

    create_fea(df)
    print(df.shape)
    print(df.columns)

    for c in [c for c in df.columns.tolist() if 'rm_diff_price_' in c]:
        df[c].fillna(0, inplace=True)
    
    #df.dropna(inplace = True)
    df.shape

    cat_feats = (['item_id','store_id', 'cat_id', 'state_id'] 
                 + ["event_type_1", "event_type_2"]
                 + ['wday', 'month', 'snap_CA', 'snap_TX', 'snap_WI'])
    
    useless_cols = ["id", "date", "sales","d", "wm_yr_wk", "weekday", "dept_id", "sell_price",'event_name_1', 'event_name_2']
    train_cols = df.columns[~df.columns.isin(useless_cols)]

    #days_val = df['d'].unique().tolist()[-200:]
    days_val = random.choices(df['d'].unique().tolist(), k=500)
    X_train = df[df['d'].isin(days_val)==False][train_cols]
    y_train = df[df['d'].isin(days_val)==False]["sales"]
    X_val = df[df['d'].isin(days_val)==True][train_cols]
    y_val = df[df['d'].isin(days_val)==True]["sales"]

    train_data = lgb.Dataset(X_train, label = y_train, categorical_feature=cat_feats)
    valid_data = lgb.Dataset(X_val, label = y_val, categorical_feature=cat_feats)

    params = {
            "objective" : "poisson",
            "metric" :"poisson",
            "learning_rate" : 0.09,
            "sub_feature" : 0.9,
            "sub_row" : 0.75,
            "bagging_freq" : 1,
            "lambda_l2" : 0.1,
            'verbosity': 1,
            'num_iterations' : 2000,
            'num_leaves': 32,
            "min_data_in_leaf": 50,
    }

    m_lgb = lgb.train(params, train_data, valid_sets = [train_data, valid_data], 
                      verbose_eval=20, early_stopping_rounds=30) 
    
    feature_imp = pd.DataFrame({'Value':m_lgb.feature_importance(),'Feature':X_train.columns})
    feature_imp = feature_imp.sort_values(by='Value', ascending=False).reset_index(drop=True)
    
    display(feature_imp.head(20))

    te = create_dt(False, dept=dept)
    cols = [f"F{i}" for i in range(1,29)]

    for tdelta in range(0, 28):
        day = fday + timedelta(days=tdelta)
        print(day)
        tst = te[(te.date >= day - timedelta(days=max_lags)) & (te.date <= day)].copy()
        create_fea(tst)
        tst = tst.loc[tst.date == day , train_cols]
        te.loc[te.date == day, "sales"] = m_lgb.predict(tst)
        del(tst)

    del(m_lgb)
    sub_p = pd.pivot_table(te, index='id', values='sales', columns='d').iloc[:,-28:].reset_index()
    del(te)
    sub_p_total = pd.concat([sub_p_total, sub_p])
    del(sub_p)
# Out:
# (5869396, 39)
# (5869396, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# /home/alan/.local/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/alan/.local/lib/python3.6/site-packages/lightgbm/basic.py:1291: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: 0.45416	valid_1's poisson: 0.460645
# [40]	training's poisson: 0.378036	valid_1's poisson: 0.386472
# [60]	training's poisson: 0.357185	valid_1's poisson: 0.366982
# [80]	training's poisson: 0.349635	valid_1's poisson: 0.360501
# [100]	training's poisson: 0.345468	valid_1's poisson: 0.357264
# [120]	training's poisson: 0.342798	valid_1's poisson: 0.355558
# [140]	training's poisson: 0.340673	valid_1's poisson: 0.354244
# [160]	training's poisson: 0.338926	valid_1's poisson: 0.353234
# [180]	training's poisson: 0.337443	valid_1's poisson: 0.352394
# [200]	training's poisson: 0.336045	valid_1's poisson: 0.351785
# [220]	training's poisson: 0.334884	valid_1's poisson: 0.351253
# [240]	training's poisson: 0.333809	valid_1's poisson: 0.350721
# [260]	training's poisson: 0.332834	valid_1's poisson: 0.350365
# [280]	training's poisson: 0.331944	valid_1's poisson: 0.349994
# [300]	training's poisson: 0.331112	valid_1's poisson: 0.349747
# [320]	training's poisson: 0.330259	valid_1's poisson: 0.349474
# [340]	training's poisson: 0.329535	valid_1's poisson: 0.349224
# [360]	training's poisson: 0.328846	valid_1's poisson: 0.349081
# [380]	training's poisson: 0.328225	valid_1's poisson: 0.348882
# [400]	training's poisson: 0.327576	valid_1's poisson: 0.348685
# [420]	training's poisson: 0.326933	valid_1's poisson: 0.348405
# [440]	training's poisson: 0.326362	valid_1's poisson: 0.348326
# [460]	training's poisson: 0.32574	valid_1's poisson: 0.348196
# [480]	training's poisson: 0.325264	valid_1's poisson: 0.348165
# [500]	training's poisson: 0.32469	valid_1's poisson: 0.348094
# [520]	training's poisson: 0.324201	valid_1's poisson: 0.347982
# [540]	training's poisson: 0.323739	valid_1's poisson: 0.347927
# [560]	training's poisson: 0.323249	valid_1's poisson: 0.347818
# [580]	training's poisson: 0.32277	valid_1's poisson: 0.347775
# [600]	training's poisson: 0.322319	valid_1's poisson: 0.347736
# [620]	training's poisson: 0.32181	valid_1's poisson: 0.347586
# [640]	training's poisson: 0.321297	valid_1's poisson: 0.347447
# [660]	training's poisson: 0.320824	valid_1's poisson: 0.347359
# [680]	training's poisson: 0.320356	valid_1's poisson: 0.347288
# [700]	training's poisson: 0.319912	valid_1's poisson: 0.347144
# [720]	training's poisson: 0.319445	valid_1's poisson: 0.347061
# [740]	training's poisson: 0.319029	valid_1's poisson: 0.347024
# [760]	training's poisson: 0.318595	valid_1's poisson: 0.346961
# [780]	training's poisson: 0.318203	valid_1's poisson: 0.346914
# [800]	training's poisson: 0.317828	valid_1's poisson: 0.346871
# [820]	training's poisson: 0.317447	valid_1's poisson: 0.346847
# [840]	training's poisson: 0.317047	valid_1's poisson: 0.346809
# [860]	training's poisson: 0.316653	valid_1's poisson: 0.346786
# [880]	training's poisson: 0.31627	valid_1's poisson: 0.34677
# [900]	training's poisson: 0.315897	valid_1's poisson: 0.346703
# [920]	training's poisson: 0.315508	valid_1's poisson: 0.346679
# [940]	training's poisson: 0.315096	valid_1's poisson: 0.346655
# [960]	training's poisson: 0.314727	valid_1's poisson: 0.346586
# [980]	training's poisson: 0.314353	valid_1's poisson: 0.346561
# [1000]	training's poisson: 0.313955	valid_1's poisson: 0.346513
# [1020]	training's poisson: 0.31359	valid_1's poisson: 0.346511
# Early stopping, best iteration is:
# [1005]	training's poisson: 0.313863	valid_1's poisson: 0.346502
#     Value                      Feature
# 0    8622                      item_id
# 1    2352                  rmean_28_28
# 2    2126                   rmean_7_28
# 3    2107                     store_id
# 4    2017                        month
# 5    1933                    rmean_7_7
# 6    1754                   rmean_28_7
# 7    1559                         wday
# 8    1321                        lag_7
# 9    1222                       lag_28
# 10   1155                         mday
# 11    872                         week
# 12    567                         year
# 13    426              rm_diff_price_8
# 14    344              rm_diff_price_4
# 15    316  event_name_1_Ramadan starts
# 16    231                     state_id
# 17    227      event_name_1_Pesach End
# 18    197                 event_type_1
# 19    197     event_name_1_MemorialDay
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# (2125531, 39)
# (2125531, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: 0.432393	valid_1's poisson: 0.429339
# [40]	training's poisson: 0.413508	valid_1's poisson: 0.411182
# [60]	training's poisson: 0.406563	valid_1's poisson: 0.404665
# [80]	training's poisson: 0.403169	valid_1's poisson: 0.401742
# [100]	training's poisson: 0.40092	valid_1's poisson: 0.400123
# [120]	training's poisson: 0.399231	valid_1's poisson: 0.399004
# [140]	training's poisson: 0.397842	valid_1's poisson: 0.398337
# [160]	training's poisson: 0.396704	valid_1's poisson: 0.397872
# [180]	training's poisson: 0.395634	valid_1's poisson: 0.3974
# [200]	training's poisson: 0.394693	valid_1's poisson: 0.397042
# [220]	training's poisson: 0.393865	valid_1's poisson: 0.396775
# [240]	training's poisson: 0.393071	valid_1's poisson: 0.396546
# [260]	training's poisson: 0.392393	valid_1's poisson: 0.396392
# [280]	training's poisson: 0.391721	valid_1's poisson: 0.396236
# [300]	training's poisson: 0.391112	valid_1's poisson: 0.396108
# [320]	training's poisson: 0.390493	valid_1's poisson: 0.395981
# [340]	training's poisson: 0.389893	valid_1's poisson: 0.395853
# [360]	training's poisson: 0.389278	valid_1's poisson: 0.39571
# [380]	training's poisson: 0.388723	valid_1's poisson: 0.395593
# [400]	training's poisson: 0.388181	valid_1's poisson: 0.395495
# [420]	training's poisson: 0.38769	valid_1's poisson: 0.395411
# [440]	training's poisson: 0.387189	valid_1's poisson: 0.39534
# [460]	training's poisson: 0.386697	valid_1's poisson: 0.39523
# [480]	training's poisson: 0.386228	valid_1's poisson: 0.395188
# [500]	training's poisson: 0.385748	valid_1's poisson: 0.395115
# [520]	training's poisson: 0.385344	valid_1's poisson: 0.395035
# [540]	training's poisson: 0.384862	valid_1's poisson: 0.394972
# [560]	training's poisson: 0.384428	valid_1's poisson: 0.394924
# [580]	training's poisson: 0.383992	valid_1's poisson: 0.394874
# [600]	training's poisson: 0.383585	valid_1's poisson: 0.394814
# [620]	training's poisson: 0.383156	valid_1's poisson: 0.394774
# [640]	training's poisson: 0.382748	valid_1's poisson: 0.394728
# [660]	training's poisson: 0.382333	valid_1's poisson: 0.394651
# [680]	training's poisson: 0.381912	valid_1's poisson: 0.394614
# [700]	training's poisson: 0.381541	valid_1's poisson: 0.394595
# [720]	training's poisson: 0.381153	valid_1's poisson: 0.394547
# [740]	training's poisson: 0.380783	valid_1's poisson: 0.394518
# [760]	training's poisson: 0.380402	valid_1's poisson: 0.394482
# [780]	training's poisson: 0.380036	valid_1's poisson: 0.394439
# [800]	training's poisson: 0.379668	valid_1's poisson: 0.39441
# [820]	training's poisson: 0.379289	valid_1's poisson: 0.394394
# [840]	training's poisson: 0.378909	valid_1's poisson: 0.394331
# [860]	training's poisson: 0.37853	valid_1's poisson: 0.394281
# [880]	training's poisson: 0.37819	valid_1's poisson: 0.39424
# [900]	training's poisson: 0.377842	valid_1's poisson: 0.394235
# [920]	training's poisson: 0.377486	valid_1's poisson: 0.394176
# [940]	training's poisson: 0.377149	valid_1's poisson: 0.394161
# [960]	training's poisson: 0.376824	valid_1's poisson: 0.394134
# [980]	training's poisson: 0.376496	valid_1's poisson: 0.394105
# [1000]	training's poisson: 0.37618	valid_1's poisson: 0.394088
# [1020]	training's poisson: 0.375857	valid_1's poisson: 0.394075
# [1040]	training's poisson: 0.375519	valid_1's poisson: 0.394035
# [1060]	training's poisson: 0.375212	valid_1's poisson: 0.394021
# [1080]	training's poisson: 0.374884	valid_1's poisson: 0.393981
# [1100]	training's poisson: 0.37455	valid_1's poisson: 0.393973
# [1120]	training's poisson: 0.374226	valid_1's poisson: 0.393955
# [1140]	training's poisson: 0.373924	valid_1's poisson: 0.393937
# [1160]	training's poisson: 0.3736	valid_1's poisson: 0.393928
# [1180]	training's poisson: 0.373301	valid_1's poisson: 0.393919
# [1200]	training's poisson: 0.372974	valid_1's poisson: 0.393918
# [1220]	training's poisson: 0.372661	valid_1's poisson: 0.393906
# [1240]	training's poisson: 0.372353	valid_1's poisson: 0.393896
# [1260]	training's poisson: 0.372043	valid_1's poisson: 0.393873
# [1280]	training's poisson: 0.371747	valid_1's poisson: 0.393853
# [1300]	training's poisson: 0.371433	valid_1's poisson: 0.39383
# [1320]	training's poisson: 0.371141	valid_1's poisson: 0.393811
# [1340]	training's poisson: 0.370853	valid_1's poisson: 0.393789
# [1360]	training's poisson: 0.37056	valid_1's poisson: 0.393775
# [1380]	training's poisson: 0.370275	valid_1's poisson: 0.393747
# [1400]	training's poisson: 0.37001	valid_1's poisson: 0.393747
# [1420]	training's poisson: 0.369749	valid_1's poisson: 0.393741
# [1440]	training's poisson: 0.369474	valid_1's poisson: 0.393739
# [1460]	training's poisson: 0.3692	valid_1's poisson: 0.393747
# Early stopping, best iteration is:
# [1432]	training's poisson: 0.369581	valid_1's poisson: 0.393737
#     Value                      Feature
# 0   11475                      item_id
# 1    3623                  rmean_28_28
# 2    3496                     store_id
# 3    3418                   rmean_7_28
# 4    3043                        month
# 5    2210                    rmean_7_7
# 6    2163                         mday
# 7    2104                         wday
# 8    1896                         week
# 9    1877                   rmean_28_7
# 10   1194                         year
# 11   1005                        lag_7
# 12    895                       lag_28
# 13    614                     state_id
# 14    457              rm_diff_price_8
# 15    387    event_name_1_Mother's day
# 16    386                    group_day
# 17    359      event_name_1_Pesach End
# 18    356  event_name_1_Ramadan starts
# 19    318     event_name_1_MemorialDay
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# (7391892, 39)
# (7391892, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: 0.103841	valid_1's poisson: 0.114253
# [40]	training's poisson: -0.0314151	valid_1's poisson: -0.0176476
# [60]	training's poisson: -0.0721768	valid_1's poisson: -0.0566423
# [80]	training's poisson: -0.0886082	valid_1's poisson: -0.0715433
# [100]	training's poisson: -0.0971774	valid_1's poisson: -0.0792281
# [120]	training's poisson: -0.101715	valid_1's poisson: -0.0827905
# [140]	training's poisson: -0.105581	valid_1's poisson: -0.0856179
# [160]	training's poisson: -0.108293	valid_1's poisson: -0.0877376
# [180]	training's poisson: -0.110673	valid_1's poisson: -0.0895441
# [200]	training's poisson: -0.112834	valid_1's poisson: -0.0912218
# [220]	training's poisson: -0.114904	valid_1's poisson: -0.0928272
# [240]	training's poisson: -0.116761	valid_1's poisson: -0.0942288
# [260]	training's poisson: -0.118378	valid_1's poisson: -0.0955349
# [280]	training's poisson: -0.119767	valid_1's poisson: -0.0965853
# [300]	training's poisson: -0.121081	valid_1's poisson: -0.0975685
# [320]	training's poisson: -0.122329	valid_1's poisson: -0.0984817
# [340]	training's poisson: -0.123382	valid_1's poisson: -0.0992237
# [360]	training's poisson: -0.12441	valid_1's poisson: -0.0999171
# [380]	training's poisson: -0.125391	valid_1's poisson: -0.100608
# [400]	training's poisson: -0.126345	valid_1's poisson: -0.101196
# [420]	training's poisson: -0.127274	valid_1's poisson: -0.101796
# [440]	training's poisson: -0.128132	valid_1's poisson: -0.102366
# [460]	training's poisson: -0.128852	valid_1's poisson: -0.102862
# [480]	training's poisson: -0.129591	valid_1's poisson: -0.103327
# [500]	training's poisson: -0.130309	valid_1's poisson: -0.103795
# [520]	training's poisson: -0.130972	valid_1's poisson: -0.104218
# [540]	training's poisson: -0.131681	valid_1's poisson: -0.104688
# [560]	training's poisson: -0.132328	valid_1's poisson: -0.105153
# [580]	training's poisson: -0.13292	valid_1's poisson: -0.105524
# [600]	training's poisson: -0.133428	valid_1's poisson: -0.105781
# [620]	training's poisson: -0.134016	valid_1's poisson: -0.10617
# [640]	training's poisson: -0.134602	valid_1's poisson: -0.106552
# [660]	training's poisson: -0.135197	valid_1's poisson: -0.106896
# [680]	training's poisson: -0.135664	valid_1's poisson: -0.107155
# [1660]	training's poisson: -0.151127	valid_1's poisson: -0.1161
# [1680]	training's poisson: -0.151368	valid_1's poisson: -0.116209
# [1700]	training's poisson: -0.151613	valid_1's poisson: -0.116336
# [1720]	training's poisson: -0.151839	valid_1's poisson: -0.116466
# [1740]	training's poisson: -0.152093	valid_1's poisson: -0.11659
# [1760]	training's poisson: -0.152311	valid_1's poisson: -0.116703
# [1780]	training's poisson: -0.152575	valid_1's poisson: -0.116851
# [1800]	training's poisson: -0.152825	valid_1's poisson: -0.117008
# [1820]	training's poisson: -0.153002	valid_1's poisson: -0.117092
# [1840]	training's poisson: -0.153205	valid_1's poisson: -0.117209
# [1860]	training's poisson: -0.153387	valid_1's poisson: -0.1173
# [1880]	training's poisson: -0.153634	valid_1's poisson: -0.117417
# [1900]	training's poisson: -0.153849	valid_1's poisson: -0.117519
# [1920]	training's poisson: -0.154062	valid_1's poisson: -0.117659
# [1940]	training's poisson: -0.154254	valid_1's poisson: -0.117738
# [1960]	training's poisson: -0.154466	valid_1's poisson: -0.117865
# [1980]	training's poisson: -0.154652	valid_1's poisson: -0.117955
# [2000]	training's poisson: -0.154844	valid_1's poisson: -0.11806
# Did not meet early stopping. Best iteration is:
# [2000]	training's poisson: -0.154844	valid_1's poisson: -0.11806
#     Value                      Feature
# 0   23224                      item_id
# 1    4412                        month
# 2    4021                   rmean_7_28
# 3    3986                     store_id
# 4    3550                  rmean_28_28
# 5    3439                    rmean_7_7
# 6    2452                         week
# 7    2401                   rmean_28_7
# 8    2224                         mday
# 9    1936                         year
# 10   1810                         wday
# 11   1494                        lag_7
# 12    904                       lag_28
# 13    616                     state_id
# 14    472              rm_diff_price_8
# 15    465                    group_day
# 16    464  event_name_1_Ramadan starts
# 17    427      event_name_1_Pesach End
# 18    389                 event_type_1
# 19    316    event_name_1_Father's day
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# (7224773, 39)
# (7224773, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: 0.529148	valid_1's poisson: 0.531058
# [40]	training's poisson: 0.502463	valid_1's poisson: 0.504988
# [60]	training's poisson: 0.493747	valid_1's poisson: 0.496761
# [2000]	training's poisson: 0.469555	valid_1's poisson: 0.482492
# Did not meet early stopping. Best iteration is:
# [2000]	training's poisson: 0.469555	valid_1's poisson: 0.482492
#     Value                      Feature
# 0   25172                      item_id
# 1    4291                     store_id
# 2    4276                        month
# 3    4262                   rmean_7_28
# 4    3382                  rmean_28_28
# 5    2473                    rmean_7_7
# 6    2237                         week
# 7    1941                         mday
# 8    1903                         wday
# 9    1746                         year
# 10   1457                   rmean_28_7
# 11    858                        lag_7
# 12    636              rm_diff_price_8
# 13    615                       lag_28
# 14    509                     state_id
# 15    495      event_name_1_Pesach End
# 16    492  event_name_1_Ramadan starts
# 17    448    event_name_1_Father's day
# 18    428                    group_day
# 19    379                 event_type_1
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# (3025995, 39)
# (3025995, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: 0.0585062	valid_1's poisson: 0.066932
# [40]	training's poisson: -0.0760252	valid_1's poisson: -0.064886
# [60]	training's poisson: -0.116923	valid_1's poisson: -0.10284
# [80]	training's poisson: -0.134691	valid_1's poisson: -0.118242
# [100]	training's poisson: -0.144832	valid_1's poisson: -0.125452
# [120]	training's poisson: -0.151301	valid_1's poisson: -0.12951
# [140]	training's poisson: -0.156331	valid_1's poisson: -0.132482
# [160]	training's poisson: -0.160565	valid_1's poisson: -0.134881
# [180]	training's poisson: -0.16443	valid_1's poisson: -0.13731
# [200]	training's poisson: -0.167691	valid_1's poisson: -0.139937
# [220]	training's poisson: -0.170679	valid_1's poisson: -0.141926
# [240]	training's poisson: -0.173217	valid_1's poisson: -0.143514
# [260]	training's poisson: -0.175383	valid_1's poisson: -0.144887
# [280]	training's poisson: -0.177675	valid_1's poisson: -0.146613
# [300]	training's poisson: -0.179587	valid_1's poisson: -0.147919
# [320]	training's poisson: -0.181547	valid_1's poisson: -0.14908
# [340]	training's poisson: -0.183208	valid_1's poisson: -0.150164
# [360]	training's poisson: -0.184691	valid_1's poisson: -0.15109
# [380]	training's poisson: -0.186136	valid_1's poisson: -0.151784
# [400]	training's poisson: -0.18739	valid_1's poisson: -0.152382
# [420]	training's poisson: -0.188553	valid_1's poisson: -0.153012
# [1400]	training's poisson: -0.22425	valid_1's poisson: -0.169497
# [1420]	training's poisson: -0.224767	valid_1's poisson: -0.169576
# [1440]	training's poisson: -0.22529	valid_1's poisson: -0.169826
# [1460]	training's poisson: -0.225809	valid_1's poisson: -0.170066
# [1480]	training's poisson: -0.226306	valid_1's poisson: -0.170243
# [1500]	training's poisson: -0.226789	valid_1's poisson: -0.170468
# [1520]	training's poisson: -0.227321	valid_1's poisson: -0.170677
# [1540]	training's poisson: -0.22786	valid_1's poisson: -0.17094
# [1560]	training's poisson: -0.228314	valid_1's poisson: -0.171139
# [1580]	training's poisson: -0.228764	valid_1's poisson: -0.171338
# [1600]	training's poisson: -0.229216	valid_1's poisson: -0.171558
# [1620]	training's poisson: -0.229708	valid_1's poisson: -0.171751
# [1640]	training's poisson: -0.230178	valid_1's poisson: -0.171975
# [1660]	training's poisson: -0.230601	valid_1's poisson: -0.172161
# [1680]	training's poisson: -0.231087	valid_1's poisson: -0.172382
# [1700]	training's poisson: -0.231505	valid_1's poisson: -0.172519
# [1720]	training's poisson: -0.231969	valid_1's poisson: -0.17274
# [1740]	training's poisson: -0.232403	valid_1's poisson: -0.172919
# [1760]	training's poisson: -0.232799	valid_1's poisson: -0.173088
# [1780]	training's poisson: -0.233269	valid_1's poisson: -0.172762
# Early stopping, best iteration is:
# [1763]	training's poisson: -0.232852	valid_1's poisson: -0.173101
#     Value                      Feature
# 0   16364                      item_id
# 1    4282                     store_id
# 2    4066                        month
# 3    3848                  rmean_28_28
# 4    3842                   rmean_7_28
# 5    3470                    rmean_7_7
# 6    2513                         week
# 7    2375                   rmean_28_7
# 8    2088                         mday
# 9    1708                         wday
# 10   1546                         year
# 11   1451                        lag_7
# 12   1022                       lag_28
# 13    512                     state_id
# 14    467                    group_day
# 15    454      event_name_1_Pesach End
# 16    443  event_name_1_Ramadan starts
# 17    424              rm_diff_price_8
# 18    395                 event_type_1
# 19    340    event_name_1_Mother's day
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# (5556345, 39)
# (5556345, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: 0.273099	valid_1's poisson: 0.27631
# [40]	training's poisson: 0.152081	valid_1's poisson: 0.156476
# [60]	training's poisson: 0.112669	valid_1's poisson: 0.118214
# [80]	training's poisson: 0.0949891	valid_1's poisson: 0.101882
# [100]	training's poisson: 0.085725	valid_1's poisson: 0.0935686
# [120]	training's poisson: 0.0804773	valid_1's poisson: 0.0891198
# [140]	training's poisson: 0.0763258	valid_1's poisson: 0.0860662
# [160]	training's poisson: 0.0730454	valid_1's poisson: 0.0836396
# [180]	training's poisson: 0.0703645	valid_1's poisson: 0.0813509
# [200]	training's poisson: 0.0678075	valid_1's poisson: 0.0792922
# [220]	training's poisson: 0.0654711	valid_1's poisson: 0.0774182
# [240]	training's poisson: 0.0634763	valid_1's poisson: 0.0757833
# [260]	training's poisson: 0.0618793	valid_1's poisson: 0.0746762
# [280]	training's poisson: 0.0602746	valid_1's poisson: 0.0732223
# [300]	training's poisson: 0.0588477	valid_1's poisson: 0.0722681
# [320]	training's poisson: 0.0574509	valid_1's poisson: 0.0712555
# [340]	training's poisson: 0.056153	valid_1's poisson: 0.0702596
# [360]	training's poisson: 0.0549949	valid_1's poisson: 0.0694516
# [380]	training's poisson: 0.0538543	valid_1's poisson: 0.0685859
# [400]	training's poisson: 0.0529	valid_1's poisson: 0.0679648
# [420]	training's poisson: 0.0519773	valid_1's poisson: 0.0673851
# [440]	training's poisson: 0.0510972	valid_1's poisson: 0.0668405
# [460]	training's poisson: 0.0503048	valid_1's poisson: 0.0662924
# [480]	training's poisson: 0.0494627	valid_1's poisson: 0.0657036
# [500]	training's poisson: 0.0487238	valid_1's poisson: 0.0651707
# [520]	training's poisson: 0.0480182	valid_1's poisson: 0.0647157
# [540]	training's poisson: 0.0473171	valid_1's poisson: 0.0642272
# [560]	training's poisson: 0.0465737	valid_1's poisson: 0.0637211
# [580]	training's poisson: 0.045955	valid_1's poisson: 0.0632877
# [600]	training's poisson: 0.0452997	valid_1's poisson: 0.0628381
# [620]	training's poisson: 0.0446903	valid_1's poisson: 0.0624763
# [640]	training's poisson: 0.0441256	valid_1's poisson: 0.0621555
# [660]	training's poisson: 0.0434609	valid_1's poisson: 0.0617109
# [680]	training's poisson: 0.0427643	valid_1's poisson: 0.0612738
# [700]	training's poisson: 0.0422064	valid_1's poisson: 0.060967
# [720]	training's poisson: 0.0415922	valid_1's poisson: 0.0605578
# [740]	training's poisson: 0.0409775	valid_1's poisson: 0.0601734
# [760]	training's poisson: 0.0404965	valid_1's poisson: 0.0599235
# [780]	training's poisson: 0.0400092	valid_1's poisson: 0.0596296
# [800]	training's poisson: 0.0395662	valid_1's poisson: 0.0593165
# [820]	training's poisson: 0.0390841	valid_1's poisson: 0.0590318
# [840]	training's poisson: 0.0386189	valid_1's poisson: 0.0587433
# [860]	training's poisson: 0.0381774	valid_1's poisson: 0.0584607
# [880]	training's poisson: 0.0377276	valid_1's poisson: 0.0581883
# [900]	training's poisson: 0.0372201	valid_1's poisson: 0.0578749
# [920]	training's poisson: 0.0367597	valid_1's poisson: 0.0576036
# [940]	training's poisson: 0.036321	valid_1's poisson: 0.0573519
# [960]	training's poisson: 0.0358974	valid_1's poisson: 0.0571087
# [1880]	training's poisson: 0.0211247	valid_1's poisson: 0.0486615
# [1900]	training's poisson: 0.0208898	valid_1's poisson: 0.048564
# [1920]	training's poisson: 0.0206321	valid_1's poisson: 0.0484213
# [1940]	training's poisson: 0.0204048	valid_1's poisson: 0.0483108
# [1960]	training's poisson: 0.020164	valid_1's poisson: 0.0481882
# [1980]	training's poisson: 0.0199145	valid_1's poisson: 0.0480689
# [2000]	training's poisson: 0.0196928	valid_1's poisson: 0.0479648
# Did not meet early stopping. Best iteration is:
# [2000]	training's poisson: 0.0196928	valid_1's poisson: 0.0479648
#     Value                      Feature
# 0   21670                      item_id
# 1    4779                        month
# 2    4203                     store_id
# 3    4010                   rmean_7_28
# 4    3404                  rmean_28_28
# 5    3372                    rmean_7_7
# 6    2732                         week
# 7    2427                         mday
# 8    2366                   rmean_28_7
# 9    2349                         year
# 10   1722                         wday
# 11   1492                        lag_7
# 12   1037                       lag_28
# 13    649                     state_id
# 14    532                    group_day
# 15    493      event_name_1_Pesach End
# 16    433              rm_diff_price_8
# 17    419                 event_type_1
# 18    410  event_name_1_Ramadan starts
# 19    366  event_name_2_OrthodoxEaster
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# (11324376, 39)
# (11324376, 48)
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'group_day',
#        'event_name_1_Cinco De Mayo', 'event_name_1_Father's day',
#        'event_name_1_MemorialDay', 'event_name_1_Mother's day',
#        'event_name_1_NBAFinalsEnd', 'event_name_1_NBAFinalsStart',
#        'event_name_1_OrthodoxEaster', 'event_name_1_Pesach End',
#        'event_name_1_Ramadan starts', 'event_name_2_Cinco De Mayo',
#        'event_name_2_Father's day', 'event_name_2_OrthodoxEaster',
#        'sell_price', 'rm_diff_price_1', 'rm_diff_price_2', 'rm_diff_price_4',
#        'rm_diff_price_8', 'lag_7', 'lag_28', 'rmean_7_7', 'rmean_28_7',
#        'rmean_7_28', 'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')
# Training until validation scores don't improve for 30 rounds
# [20]	training's poisson: -1.15928	valid_1's poisson: -1.17743
# [40]	training's poisson: -1.40199	valid_1's poisson: -1.41671
# [60]	training's poisson: -1.47373	valid_1's poisson: -1.48652
# [80]	training's poisson: -1.5022	valid_1's poisson: -1.51384
# [100]	training's poisson: -1.51762	valid_1's poisson: -1.52801
# [120]	training's poisson: -1.52675	valid_1's poisson: -1.5361
# [140]	training's poisson: -1.53337	valid_1's poisson: -1.54167
# [160]	training's poisson: -1.53856	valid_1's poisson: -1.54616
# [180]	training's poisson: -1.54313	valid_1's poisson: -1.55001
# [200]	training's poisson: -1.54728	valid_1's poisson: -1.55333
# [220]	training's poisson: -1.55098	valid_1's poisson: -1.55654
# [240]	training's poisson: -1.55419	valid_1's poisson: -1.5591
# [260]	training's poisson: -1.55734	valid_1's poisson: -1.56168
# [280]	training's poisson: -1.56031	valid_1's poisson: -1.564
# [1260]	training's poisson: -1.61174	valid_1's poisson: -1.60003
# [1280]	training's poisson: -1.61224	valid_1's poisson: -1.60033
# [1300]	training's poisson: -1.61272	valid_1's poisson: -1.6006
# [1320]	training's poisson: -1.61324	valid_1's poisson: -1.60083
# [1340]	training's poisson: -1.61377	valid_1's poisson: -1.60117
# [1360]	training's poisson: -1.61431	valid_1's poisson: -1.60145
# [1380]	training's poisson: -1.61478	valid_1's poisson: -1.60172
# [1400]	training's poisson: -1.6153	valid_1's poisson: -1.60201
# [1420]	training's poisson: -1.61574	valid_1's poisson: -1.60224
# [1440]	training's poisson: -1.61614	valid_1's poisson: -1.60243
# [1460]	training's poisson: -1.6166	valid_1's poisson: -1.60275
# [1480]	training's poisson: -1.6171	valid_1's poisson: -1.60303
# [1500]	training's poisson: -1.61761	valid_1's poisson: -1.60336
# [1520]	training's poisson: -1.61804	valid_1's poisson: -1.60363
# [1540]	training's poisson: -1.61849	valid_1's poisson: -1.60386
# [1560]	training's poisson: -1.61897	valid_1's poisson: -1.60416
# [1580]	training's poisson: -1.61939	valid_1's poisson: -1.6044
# [1600]	training's poisson: -1.61979	valid_1's poisson: -1.60466
# [1620]	training's poisson: -1.62014	valid_1's poisson: -1.60483
# [1640]	training's poisson: -1.62054	valid_1's poisson: -1.60507
# [1660]	training's poisson: -1.62099	valid_1's poisson: -1.60535
# [1680]	training's poisson: -1.62135	valid_1's poisson: -1.60553
# [1700]	training's poisson: -1.62171	valid_1's poisson: -1.60577
# [1720]	training's poisson: -1.62211	valid_1's poisson: -1.60602
# [1740]	training's poisson: -1.62254	valid_1's poisson: -1.6063
# [1760]	training's poisson: -1.62291	valid_1's poisson: -1.60648
# [1780]	training's poisson: -1.62324	valid_1's poisson: -1.60663
# [1800]	training's poisson: -1.62367	valid_1's poisson: -1.60688
# [1820]	training's poisson: -1.62405	valid_1's poisson: -1.60708
# [1840]	training's poisson: -1.62439	valid_1's poisson: -1.60724
# [1860]	training's poisson: -1.62475	valid_1's poisson: -1.60744
# [1880]	training's poisson: -1.62524	valid_1's poisson: -1.60775
# [1900]	training's poisson: -1.62559	valid_1's poisson: -1.60791
# [1920]	training's poisson: -1.62596	valid_1's poisson: -1.60808
# [1940]	training's poisson: -1.62632	valid_1's poisson: -1.60833
# [1960]	training's poisson: -1.62664	valid_1's poisson: -1.6085
# [1980]	training's poisson: -1.62699	valid_1's poisson: -1.60867
# [2000]	training's poisson: -1.62733	valid_1's poisson: -1.60885
# Did not meet early stopping. Best iteration is:
# [2000]	training's poisson: -1.62733	valid_1's poisson: -1.60885
#     Value                      Feature
# 0   21287                      item_id
# 1    4448                        month
# 2    4078                    rmean_7_7
# 3    3955                   rmean_7_28
# 4    3612                  rmean_28_28
# 5    3517                     store_id
# 6    2701                   rmean_28_7
# 7    2579                        lag_7
# 8    2365                         week
# 9    2343                         mday
# 10   1794                         wday
# 11   1720                         year
# 12   1690                       lag_28
# 13    585                     state_id
# 14    532                    group_day
# 15    389  event_name_1_Ramadan starts
# 16    385              rm_diff_price_8
# 17    353                 event_type_1
# 18    310     event_name_1_MemorialDay
# 19    300      event_name_1_Pesach End
# 2016-05-23 00:00:00
# 2016-05-24 00:00:00
# 2016-05-25 00:00:00
# 2016-05-26 00:00:00
# 2016-05-27 00:00:00
# 2016-05-28 00:00:00
# 2016-05-29 00:00:00
# 2016-05-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-01 00:00:00
# 2016-06-02 00:00:00
# 2016-06-03 00:00:00
# 2016-06-04 00:00:00
# 2016-06-05 00:00:00
# 2016-06-06 00:00:00
# 2016-06-07 00:00:00
# 2016-06-08 00:00:00
# 2016-06-09 00:00:00
# 2016-06-10 00:00:00
# 2016-06-11 00:00:00
# 2016-06-12 00:00:00
# 2016-06-13 00:00:00
# 2016-06-14 00:00:00
# 2016-06-15 00:00:00
# 2016-06-16 00:00:00
# 2016-06-17 00:00:00
# 2016-06-18 00:00:00
# 2016-06-19 00:00:00
# CPU times: user 7h 14min, sys: 30.6 s, total: 7h 14min 31s
# Wall time: 2h 17min 51s

# %%
sub_p_total.shape
# Out:
# (30490, 29)

# %%
sub_p_total.tail()
# Out:
# d                              id    d_1942    d_1943    d_1944    d_1945  \
# 8225  FOODS_3_827_TX_2_evaluation  0.452905  0.393299  0.117635  0.123102
# 8226  FOODS_3_827_TX_3_evaluation  1.531034  1.338524  1.186633  1.203981
# 8227  FOODS_3_827_WI_1_evaluation  3.145475  2.995610  2.530498  2.738707
# 8228  FOODS_3_827_WI_2_evaluation  1.802031  1.721998  1.538359  1.524689
# 8229  FOODS_3_827_WI_3_evaluation  1.194020  1.193381  0.914131  1.193602
#
# d       d_1946    d_1947    d_1948    d_1949    d_1950    d_1951    d_1952  \
# 8225  0.562630  0.243517  0.342332  0.484096  0.411051  0.461842  0.456677
# 8226  1.610346  1.454457  1.209128  1.331635  1.114847  1.365433  1.245394
# 8227  3.971953  3.550740  3.033403  3.652720  2.946136  3.061416  2.921038
# 8228  1.903209  1.762669  1.358076  1.910003  1.690071  1.864871  2.271737
# 8229  1.493669  1.293505  0.918430  1.214310  0.979346  0.932469  1.214255
#
# d       d_1953    d_1954    d_1955    d_1956    d_1957    d_1958    d_1959  \
# 8225  0.458377  0.452162  0.460642  0.412228  0.389354  0.388544  0.436008
# 8226  1.573512  1.695297  1.824165  1.404043  1.270600  1.331796  1.395284
# 8227  3.469461  4.463633  4.008035  2.821261  2.807999  2.795520  2.944696
# 8228  2.426931  2.404684  2.719897  2.282636  1.835640  2.013013  2.196629
# 8229  1.522702  1.538968  1.761719  1.315104  1.078254  1.168156  1.305830
#
# d       d_1960    d_1961    d_1962    d_1963    d_1964    d_1965    d_1966  \
# 8225  0.458971  0.489249  0.421906  0.385017  0.306454  0.400966  0.396558
# 8226  1.514368  1.724660  1.509810  1.190785  0.953507  0.934842  0.916055
# 8227  3.633557  4.081847  3.427531  2.358791  2.091673  2.079195  2.116285
# 8228  1.972379  2.571123  2.168764  1.489603  1.497055  1.570503  1.292173
# 8229  1.231271  1.739784  1.445818  0.962981  1.013298  1.054786  0.931416
#
# d       d_1967    d_1968    d_1969
# 8225  0.299902  0.349158  0.327489
# 8226  1.124167  1.349973  1.247266
# 8227  2.565604  3.120374  2.698086
# 8228  1.450243  1.756658  1.496431
# 8229  1.026663  1.381871  1.203128

# %%
sub = pd.read_csv('./raw_data/sample_submission.csv', usecols=['id'])

# %%
sub = sub.merge(sub_p_total, on='id', how='left')

# %%
sub = sub.dropna()

# %%
sub2 = sub.copy()
sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
sub = pd.concat([sub, sub2], axis=0, sort=False)
sub.columns = ['id'] + ['F' + str(c) for c in np.arange(1,29,1)]
sub.to_csv("./proc_data/partial_submission.csv",index=False)
